# %% [markdown]
# **Mayur Pralhad Musale**

# %% [markdown]
# **Registration ID : SIRSS1240**

# %% [markdown]
# **Assignment No : 11    (Leaf Classification)**

# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv('train.csv.zip', index_col ='id')
test_data = pd.read_csv('test.csv.zip')

# %%
test_ids = test_data.id
test_data = test_data.drop(['id'], axis =1)

# %%
#Data Preprocessing
train_data.head()
# Out:
#                   species   margin1   margin2   margin3   margin4   margin5  \
# id
# 1             Acer_Opalus  0.007812  0.023438  0.023438  0.003906  0.011719
# 2   Pterocarya_Stenoptera  0.005859  0.000000  0.031250  0.015625  0.025391
# 3    Quercus_Hartwissiana  0.005859  0.009766  0.019531  0.007812  0.003906
# 5         Tilia_Tomentosa  0.000000  0.003906  0.023438  0.005859  0.021484
# 6      Quercus_Variabilis  0.005859  0.003906  0.048828  0.009766  0.013672
#
#      margin6   margin7  margin8   margin9  ...  texture55  texture56  \
# id                                         ...
# 1   0.009766  0.027344      0.0  0.001953  ...   0.007812   0.000000
# 2   0.001953  0.019531      0.0  0.000000  ...   0.000977   0.000000
# 3   0.005859  0.068359      0.0  0.000000  ...   0.154300   0.000000
# 5   0.019531  0.023438      0.0  0.013672  ...   0.000000   0.000977
# 6   0.015625  0.005859      0.0  0.000000  ...   0.096680   0.000000
#
# ...

# %%
train_data.tail()
# Out:
#                    species   margin1   margin2   margin3   margin4   margin5  \
# id
# 1575  Magnolia_Salicifolia  0.060547  0.119140  0.007812  0.003906  0.000000
# 1578           Acer_Pictum  0.001953  0.003906  0.021484  0.107420  0.001953
# 1581    Alnus_Maximowiczii  0.001953  0.003906  0.000000  0.021484  0.078125
# 1582         Quercus_Rubra  0.000000  0.000000  0.046875  0.056641  0.009766
# 1584        Quercus_Afares  0.023438  0.019531  0.031250  0.015625  0.005859
#
#        margin6   margin7  margin8   margin9  ...  texture55  texture56  \
# id                                           ...
# 1575  0.148440  0.017578      0.0  0.001953  ...   0.242190   0.000000
# 1578  0.000000  0.000000      0.0  0.029297  ...   0.170900   0.000000
# 1581  0.003906  0.007812      0.0  0.003906  ...   0.004883   0.000977
# 1582  0.000000  0.000000      0.0  0.037109  ...   0.083008   0.030273
# 1584  0.019531  0.035156      0.0  0.003906  ...   0.000000   0.000000
#
# ...

# %%
test_data.isnull().any().sum()
# Out:
# 0

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 990 entries, 1 to 1584
# Columns: 193 entries, species to texture64
# dtypes: float64(192), object(1)
# memory usage: 1.5+ MB

# %%
test_data.shape
# Out:
# (594, 192)

# %%
train_data.describe()
# Out:
#           margin1     margin2     margin3     margin4     margin5     margin6  \
# count  990.000000  990.000000  990.000000  990.000000  990.000000  990.000000
# mean     0.017412    0.028539    0.031988    0.023280    0.014264    0.038579
# std      0.019739    0.038855    0.025847    0.028411    0.018390    0.052030
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.001953    0.001953    0.013672    0.005859    0.001953    0.000000
# 50%      0.009766    0.011719    0.025391    0.013672    0.007812    0.015625
# 75%      0.025391    0.041016    0.044922    0.029297    0.017578    0.056153
# max      0.087891    0.205080    0.156250    0.169920    0.111330    0.310550
#
#           margin7     margin8     margin9    margin10  ...   texture55  \
# count  990.000000  990.000000  990.000000  990.000000  ...  990.000000
# mean     0.019202    0.001083    0.007167    0.018639  ...    0.036501
# ...

# %%
train_data.describe().T
# Out:
#            count      mean       std  min       25%       50%       75%  \
# margin1    990.0  0.017412  0.019739  0.0  0.001953  0.009766  0.025391
# margin2    990.0  0.028539  0.038855  0.0  0.001953  0.011719  0.041016
# margin3    990.0  0.031988  0.025847  0.0  0.013672  0.025391  0.044922
# margin4    990.0  0.023280  0.028411  0.0  0.005859  0.013672  0.029297
# margin5    990.0  0.014264  0.018390  0.0  0.001953  0.007812  0.017578
# ...          ...       ...       ...  ...       ...       ...       ...
# texture60  990.0  0.014017  0.060151  0.0  0.000000  0.000000  0.000000
# texture61  990.0  0.002688  0.011415  0.0  0.000000  0.000000  0.000000
# texture62  990.0  0.020291  0.039040  0.0  0.000000  0.003906  0.023438
# texture63  990.0  0.008989  0.013791  0.0  0.000000  0.002930  0.012695
# texture64  990.0  0.019420  0.022768  0.0  0.000977  0.011719  0.029297
#
#                 max
# margin1    0.087891
# margin2    0.205080
# margin3    0.156250
# ...

# %%
test_data.describe()
# Out:
#           margin1     margin2     margin3     margin4     margin5     margin6  \
# count  594.000000  594.000000  594.000000  594.000000  594.000000  594.000000
# mean     0.017562    0.028425    0.031858    0.022556    0.014527    0.037497
# std      0.019585    0.038351    0.025719    0.028797    0.018029    0.051372
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.001953    0.001953    0.013672    0.005859    0.001953    0.000000
# 50%      0.009766    0.010743    0.023438    0.013672    0.007812    0.013672
# 75%      0.028809    0.041016    0.042969    0.027344    0.019531    0.056641
# max      0.085938    0.189450    0.167970    0.164060    0.093750    0.271480
#
#           margin7     margin8     margin9    margin10  ...   texture55  \
# count  594.000000  594.000000  594.000000  594.000000  ...  594.000000
# mean     0.019222    0.001085    0.007092    0.018798  ...    0.035291
# ...

# %%
test_data.describe().T
# Out:
#            count      mean       std  min       25%       50%       75%  \
# margin1    594.0  0.017562  0.019585  0.0  0.001953  0.009766  0.028809
# margin2    594.0  0.028425  0.038351  0.0  0.001953  0.010743  0.041016
# margin3    594.0  0.031858  0.025719  0.0  0.013672  0.023438  0.042969
# margin4    594.0  0.022556  0.028797  0.0  0.005859  0.013672  0.027344
# margin5    594.0  0.014527  0.018029  0.0  0.001953  0.007812  0.019531
# ...          ...       ...       ...  ...       ...       ...       ...
# texture60  594.0  0.011217  0.052530  0.0  0.000000  0.000000  0.000000
# texture61  594.0  0.002617  0.011204  0.0  0.000000  0.000000  0.000000
# texture62  594.0  0.019975  0.034704  0.0  0.000000  0.003418  0.022461
# texture63  594.0  0.009389  0.013457  0.0  0.000000  0.002930  0.014648
# texture64  594.0  0.020970  0.023407  0.0  0.000977  0.013184  0.032227
#
#                 max
# margin1    0.085938
# margin2    0.189450
# margin3    0.167970
# ...

# %%
train_data['species'].nunique()
# Out:
# 99

# %%
x = train_data.drop('species',axis=1)
y = train_data['species']

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
y_fit = encoder.fit(train_data['species'])
y_label = y_fit.transform(train_data['species']) 
classes = list(y_fit.classes_) 
classes
# Out:
# ['Acer_Capillipes',
#  'Acer_Circinatum',
#  'Acer_Mono',
#  'Acer_Opalus',
#  'Acer_Palmatum',
#  'Acer_Pictum',
#  'Acer_Platanoids',
#  'Acer_Rubrum',
#  'Acer_Rufinerve',
#  'Acer_Saccharinum',
#  'Alnus_Cordata',
#  'Alnus_Maximowiczii',
#  'Alnus_Rubra',
#  'Alnus_Sieboldiana',
#  'Alnus_Viridis',
#  'Arundinaria_Simonii',
#  'Betula_Austrosinensis',
#  'Betula_Pendula',
#  'Callicarpa_Bodinieri',
#  'Castanea_Sativa',
#  'Celtis_Koraiensis',
#  'Cercis_Siliquastrum',
#  'Cornus_Chinensis',
#  'Cornus_Controversa',
#  'Cornus_Macrophylla',
#  'Cotinus_Coggygria',
#  'Crataegus_Monogyna',
#  'Cytisus_Battandieri',
#  'Eucalyptus_Glaucescens',
#  'Eucalyptus_Neglecta',
#  'Eucalyptus_Urnigera',
#  'Fagus_Sylvatica',
#  'Ginkgo_Biloba',
#  'Ilex_Aquifolium',
#  'Ilex_Cornuta',
#  'Liquidambar_Styraciflua',
#  'Liriodendron_Tulipifera',
#  'Lithocarpus_Cleistocarpus',
#  'Lithocarpus_Edulis',
#  'Magnolia_Heptapeta',
#  'Magnolia_Salicifolia',
#  'Morus_Nigra',
#  'Olea_Europaea',
# ...

# %%
from sklearn.model_selection import  train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y_label, test_size = 0.2, random_state =1)

# %%
#Model Building
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(n_estimators = 40)
classifier.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=40)

# %%
from sklearn.metrics import classification_report
predictions = classifier.predict(x_test)
print (classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         4
#            1       1.00      1.00      1.00         1
#            2       1.00      1.00      1.00         2
#            3       1.00      1.00      1.00         3
#            4       1.00      1.00      1.00         3
#            5       1.00      1.00      1.00         2
#            6       1.00      1.00      1.00         3
#            7       1.00      1.00      1.00         1
#            8       1.00      1.00      1.00         1
#            9       1.00      1.00      1.00         3
#           10       0.50      1.00      0.67         1
#           11       1.00      1.00      1.00         3
#           12       1.00      1.00      1.00         3
#           13       1.00      1.00      1.00         2
#           14       1.00      1.00      1.00         2
#           15       1.00      1.00      1.00         2
# ...

# %%
final_predictions = classifier.predict_proba(test_data)

# %%
submission = pd.DataFrame(final_predictions, columns=classes)
submission.insert(0, 'id', test_ids)
submission.reset_index()
# Out:
#      index    id  Acer_Capillipes  Acer_Circinatum  Acer_Mono  Acer_Opalus  \
# 0        0     4            0.000            0.000      0.000        0.000
# 1        1     7            0.000            0.000      0.025        0.075
# 2        2     9            0.000            0.700      0.000        0.000
# 3        3    12            0.000            0.075      0.000        0.025
# 4        4    13            0.025            0.025      0.000        0.000
# ..     ...   ...              ...              ...        ...          ...
# 589    589  1576            0.000            0.600      0.000        0.000
# 590    590  1577            0.000            0.000      0.000        0.025
# 591    591  1579            0.000            0.000      0.000        0.000
# 592    592  1580            0.000            0.000      0.000        0.000
# 593    593  1583            0.000            0.000      0.000        0.000
#
# ...

# %%
submission.to_csv('result.csv')

# %%
results_data = pd.read_csv('result.csv')

# %%
results_data.head(10)
# Out:
#    Unnamed: 0  id  Acer_Capillipes  Acer_Circinatum  Acer_Mono  Acer_Opalus  \
# 0           0   4            0.000            0.000      0.000        0.000
# 1           1   7            0.000            0.000      0.025        0.075
# 2           2   9            0.000            0.700      0.000        0.000
# 3           3  12            0.000            0.075      0.000        0.025
# 4           4  13            0.025            0.025      0.000        0.000
# 5           5  16            0.000            0.000      0.000        0.175
# 6           6  19            0.000            0.000      0.000        0.475
# 7           7  23            0.000            0.000      0.000        0.025
# 8           8  24            0.000            0.000      0.000        0.000
# 9           9  28            0.000            0.000      0.000        0.000
#
#    Acer_Palmatum  Acer_Pictum  Acer_Platanoids  Acer_Rubrum  ...  \
# 0          0.000          0.0             0.00        0.000  ...
# ...
